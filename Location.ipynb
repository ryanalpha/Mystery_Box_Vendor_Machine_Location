# %%
import folium
import pandas as pd

# %%
mystery_box = folium.Map([-6.261242, 106.812756], tiles = 'OpenStreetMap', zoom_start=18)
folium.Marker([-6.261242, 106.812756], icon = folium.Icon(color='red', icon=''), tooltip='Lippo Mall Kemang', popup = 'GF, The Peoples Cafe').add_to(mystery_box)
folium.Marker([-6.1930672, 106.8217313], icon = folium.Icon(color='red', icon=''), tooltip='Plaza Indonesia', popup = '4th, Starbucks').add_to(mystery_box)
folium.Marker([-6.150886, 106.891958], icon = folium.Icon(color='red', icon=''), tooltip='Mall of Indonesia', popup = 'GF, Salad Stop').add_to(mystery_box)
folium.Marker([-6.145774, 106.891919], icon = folium.Icon(color='red', icon=''), tooltip='Mall Artha Gading', popup = 'GF, Ace Hardware').add_to(mystery_box)
folium.Marker([-6.2408, 106.628348], icon = folium.Icon(color='red', icon=''), tooltip='Summarecon Mall Serpong', popup = '2nd, ATM Center').add_to(mystery_box)
folium.Marker([-6.193814, 106.633946], icon = folium.Icon(color='red', icon=''), tooltip='Tangerang City Mall', popup = 'GF, Lift').add_to(mystery_box)
folium.Marker([-6.16838, 106.786736], icon = folium.Icon(color='red', icon=''), tooltip='Mall Ciputra Jakarta', popup = 'LG, West Lobby Door').add_to(mystery_box)
folium.Marker([-6.375389, 106.902219], icon = folium.Icon(color='red', icon=''), tooltip='Trans Studio Mall Cibubur', popup = '3rd, Gyu-Kaku').add_to(mystery_box)
folium.Marker([-6.224466, 106.822874], icon = folium.Icon(color='red', icon=''), tooltip='Lotte Shopping Avenue', popup = 'LG, Lotte Alley').add_to(mystery_box)
folium.Marker([-6.201759, 106.782255], icon = folium.Icon(color='red', icon=''), tooltip='Binus University', popup = 'GF, Beehive Store').add_to(mystery_box)
folium.Marker([-6.242853, 106.651394], icon = folium.Icon(color='red', icon=''), tooltip='Broadway Alam Sutera', popup = 'Broadway Alley, Pasta Bar').add_to(mystery_box)

mystery_box
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
